# %%
from bs4 import BeautifulSoup

import requests

# %%
url = "https://www.tradingview.com/markets/cryptocurrencies/prices-all/"

response_data = requests.get(url)
response_content = response_data.content

# %%
soup = BeautifulSoup(response_content, "html.parser")

# %%
soup_body = soup.find_all('body')[0]
# print(soup_body.prettify())

# %%
soup_body_coin_info = soup_body.find_all('tr', class_='row-RdUXZpkv listRow')
# len(soup_body_coin_info), soup_body_coin_info

# %%
for coin_info in soup_body_coin_info:
    info_list = coin_info.find_all('td')
    
    print('NAME:\t', info_list[0].find('a')['title'])
    print('LOGO:\t', info_list[0].find('img')['src'])
    print('RANK:\t', info_list[1].text)
    print('PRICE:\t', info_list[2].text)
    print('CHANGE % IN 24H:\t', info_list[3].text)
    print('MARKET CAP:\t', info_list[4].text)
    print('CATEGORY:\t', info_list[-1].text)
    print('\n\n')
# Out:
# NAME:	 BTC − Bitcoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCBTC.svg
# RANK:	 1
# PRICE:	 28917.32 USD
# CHANGE % IN 24H:	 1.59%
# MARKET CAP:	 559.958B USD
# CATEGORY:	 Cryptocurrencies
#
#
#
# NAME:	 ETH − Ethereum
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCETH.svg
# RANK:	 2
# PRICE:	 1885.79 USD
# CHANGE % IN 24H:	 1.27%
# MARKET CAP:	 227.004B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 USDT − Tether
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCUSDT.svg
# RANK:	 3
# PRICE:	 0.99850750 USD
# CHANGE % IN 24H:	 −0.03%
# MARKET CAP:	 81.863B USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins
#
#
#
# NAME:	 BNB − BNB
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCBNB.svg
# RANK:	 4
# PRICE:	 325.18617152 USD
# CHANGE % IN 24H:	 0.63%
# MARKET CAP:	 50.684B USD
# CATEGORY:	 Smart contract platforms, Centralized exchange
#
#
#
# NAME:	 USDC − USD Coin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCUSDC.svg
# RANK:	 5
# PRICE:	 1.000458 USD
# CHANGE % IN 24H:	 0.02%
# MARKET CAP:	 30.134B USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins
#
#
#
# NAME:	 XRP − XRP
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCXRP.svg
# RANK:	 6
# PRICE:	 0.45924 USD
# CHANGE % IN 24H:	 2.04%
# MARKET CAP:	 23.774B USD
# CATEGORY:	 Cryptocurrencies, Enterprise solutions
#
#
#
# NAME:	 ADA − Cardano
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCADA.svg
# RANK:	 7
# PRICE:	 0.389923 USD
# CHANGE % IN 24H:	 2.04%
# MARKET CAP:	 13.577B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 DOGE − Dogecoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCDOGE.svg
# RANK:	 8
# PRICE:	 0.07827500 USD
# CHANGE % IN 24H:	 0.71%
# MARKET CAP:	 10.897B USD
# CATEGORY:	 Memes, Cryptocurrencies
#
#
#
# NAME:	 MATIC − Polygon
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCMATIC.svg
# RANK:	 9
# PRICE:	 0.9862 USD
# CHANGE % IN 24H:	 0.24%
# MARKET CAP:	 9.122B USD
# CATEGORY:	 Scaling
#
#
#
# NAME:	 SOL − Solana
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCSOL.svg
# RANK:	 10
# PRICE:	 21.90 USD
# CHANGE % IN 24H:	 2.62%
# MARKET CAP:	 8.631B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 DOT − Polkadot
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCDOT.svg
# RANK:	 11
# PRICE:	 5.6918 USD
# CHANGE % IN 24H:	 1.28%
# MARKET CAP:	 6.719B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 LTC − Litecoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCLTC.svg
# RANK:	 12
# PRICE:	 88.041769 USD
# CHANGE % IN 24H:	 2.19%
# MARKET CAP:	 6.414B USD
# CATEGORY:	 Cryptocurrencies
#
#
#
# NAME:	 TRX − TRON
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCTRX.svg
# RANK:	 13
# PRICE:	 0.06965413 USD
# CHANGE % IN 24H:	 0.68%
# MARKET CAP:	 6.309B USD
# CATEGORY:	 Payments, Smart contract platforms
#
#
#
# NAME:	 BUSD − Binance USD
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCBUSD.svg
# RANK:	 14
# PRICE:	 1.00019721 USD
# CHANGE % IN 24H:	 0.00%
# MARKET CAP:	 5.987B USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins
#
#
#
# NAME:	 SHIB − Shiba Inu
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCSHIB.svg
# RANK:	 15
# PRICE:	 0.00000994 USD
# CHANGE % IN 24H:	 0.51%
# MARKET CAP:	 5.86B USD
# CATEGORY:	 Memes, Cryptocurrencies
#
#
#
# NAME:	 AVAX − Avalanche
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCAVAX.svg
# RANK:	 16
# PRICE:	 16.9739348 USD
# CHANGE % IN 24H:	 2.33%
# MARKET CAP:	 5.597B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 DAI − Dai
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCDAI.svg
# RANK:	 17
# PRICE:	 0.99800110 USD
# CHANGE % IN 24H:	 −0.23%
# MARKET CAP:	 4.863B USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins, DeFi
#
#
#
# NAME:	 WBTC − Wrapped Bitcoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCWBTC.svg
# RANK:	 18
# PRICE:	 28930.9000 USD
# CHANGE % IN 24H:	 2.07%
# MARKET CAP:	 4.464B USD
# CATEGORY:	 Wrapped Tokens, Cryptocurrencies
#
#
#
# NAME:	 LINK − Chainlink
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCLINK.svg
# RANK:	 19
# PRICE:	 7.0259232 USD
# CHANGE % IN 24H:	 2.02%
# MARKET CAP:	 3.633B USD
# CATEGORY:	 Oracles, Web3, Data management & AI
#
#
#
# NAME:	 LEO − UNUS SED LEO
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCLEO.svg
# RANK:	 20
# PRICE:	 3.5475 USD
# CHANGE % IN 24H:	 −3.49%
# MARKET CAP:	 3.301B USD
# CATEGORY:	 Centralized exchange, Payments
#
#
#
# NAME:	 ATOM − Cosmos
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCATOM.svg
# RANK:	 21
# PRICE:	 10.9632059 USD
# CHANGE % IN 24H:	 1.29%
# MARKET CAP:	 3.14B USD
# CATEGORY:	 Interoperability, Smart contract platforms
#
#
#
# NAME:	 UNI − Uniswap
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCUNI.svg
# RANK:	 22
# PRICE:	 5.2843976 USD
# CHANGE % IN 24H:	 0.92%
# MARKET CAP:	 3.052B USD
# CATEGORY:	 Decentralized exchange, DeFi, DAO
#
#
#
# NAME:	 XMR − Monero
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCXMR.svg
# RANK:	 23
# PRICE:	 155.56247282 USD
# CHANGE % IN 24H:	 1.28%
# MARKET CAP:	 2.843B USD
# CATEGORY:	 Privacy, Cryptocurrencies
#
#
#
# NAME:	 OKB − OKB
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCOKB.svg
# RANK:	 24
# PRICE:	 46.537 USD
# CHANGE % IN 24H:	 0.73%
# MARKET CAP:	 2.792B USD
# CATEGORY:	 Centralized exchange
#
#
#
# NAME:	 ETC − Ethereum Classic
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCETC.svg
# RANK:	 25
# PRICE:	 19.266785 USD
# CHANGE % IN 24H:	 1.67%
# MARKET CAP:	 2.712B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 ICP − Internet Computer
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCICP.svg
# RANK:	 26
# PRICE:	 5.979 USD
# CHANGE % IN 24H:	 6.24%
# MARKET CAP:	 2.606B USD
# CATEGORY:	 Smart contract platforms, Distributed computing & Storage, NFTs & Collectibles, Interoperability, Payments, DeFi, DAO
#
#
#
# NAME:	 TON − Toncoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCTON.svg
# RANK:	 27
# PRICE:	 2.0504 USD
# CHANGE % IN 24H:	 −0.01%
# MARKET CAP:	 2.504B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 XLM − Stellar
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCXLM.svg
# RANK:	 28
# PRICE:	 0.09314000 USD
# CHANGE % IN 24H:	 1.03%
# MARKET CAP:	 2.493B USD
# CATEGORY:	 Cryptocurrencies, Smart contract platforms
#
#
#
# NAME:	 BCH − Bitcoin Cash
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCBCH.svg
# RANK:	 29
# PRICE:	 117.40781 USD
# CHANGE % IN 24H:	 0.62%
# MARKET CAP:	 2.276B USD
# CATEGORY:	 Cryptocurrencies
#
#
#
# NAME:	 TUSD − TrueUSD
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCTUSD.svg
# RANK:	 30
# PRICE:	 0.99991819 USD
# CHANGE % IN 24H:	 0.22%
# MARKET CAP:	 2.248B USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins
#
#
#
# NAME:	 FIL − Filecoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCFIL.svg
# RANK:	 31
# PRICE:	 5.2773697 USD
# CHANGE % IN 24H:	 0.48%
# MARKET CAP:	 2.223B USD
# CATEGORY:	 Distributed computing & Storage, Web3
#
#
#
# NAME:	 APT − Aptos
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCAPTO.svg
# RANK:	 32
# PRICE:	 9.72629268 USD
# CHANGE % IN 24H:	 2.41%
# MARKET CAP:	 1.847B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 HBAR − Hedera
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCHBAR.svg
# RANK:	 33
# PRICE:	 0.05774561 USD
# CHANGE % IN 24H:	 2.36%
# MARKET CAP:	 1.807B USD
# CATEGORY:	 Enterprise solutions, Smart contract platforms
#
#
#
# NAME:	 CRO − Cronos
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCCRO.svg
# RANK:	 34
# PRICE:	 0.07039348 USD
# CHANGE % IN 24H:	 −1.01%
# MARKET CAP:	 1.778B USD
# CATEGORY:	 Centralized exchange, Payments, Smart contract platforms
#
#
#
# NAME:	 ARB − Arbitrum
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCARBI.svg
# RANK:	 35
# PRICE:	 1.32866155 USD
# CHANGE % IN 24H:	 1.36%
# MARKET CAP:	 1.694B USD
# CATEGORY:	 Scaling, Web3, DAO
#
#
#
# NAME:	 LDO − Lido DAO
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCLDO.svg
# RANK:	 36
# PRICE:	 1.92694298 USD
# CHANGE % IN 24H:	 2.77%
# MARKET CAP:	 1.691B USD
# CATEGORY:	 Derivatives, DeFi, DAO
#
#
#
# NAME:	 NEAR − NEAR Protocol
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCNEAR.svg
# RANK:	 37
# PRICE:	 1.85499055 USD
# CHANGE % IN 24H:	 3.53%
# MARKET CAP:	 1.663B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 VET − VeChain
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCVET.svg
# RANK:	 38
# PRICE:	 0.02066551 USD
# CHANGE % IN 24H:	 1.23%
# MARKET CAP:	 1.498B USD
# CATEGORY:	 Smart contract platforms, Internet of things, Logistics
#
#
#
# NAME:	 APE − ApeCoin
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCAPE.svg
# RANK:	 39
# PRICE:	 3.81583019 USD
# CHANGE % IN 24H:	 0.93%
# MARKET CAP:	 1.406B USD
# CATEGORY:	 NFTs & Collectibles
#
#
#
# NAME:	 QNT − Quant
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCQNT.svg
# RANK:	 40
# PRICE:	 113.049951 USD
# CHANGE % IN 24H:	 0.96%
# MARKET CAP:	 1.365B USD
# CATEGORY:	 Interoperability
#
#
#
# NAME:	 ALGO − Algorand
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCALGO.svg
# RANK:	 41
# PRICE:	 0.17683902 USD
# CHANGE % IN 24H:	 0.59%
# MARKET CAP:	 1.278B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 FTM − Fantom
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCFTM.svg
# RANK:	 42
# PRICE:	 0.431775 USD
# CHANGE % IN 24H:	 3.67%
# MARKET CAP:	 1.204B USD
# CATEGORY:	 Smart contract platforms, Enterprise solutions
#
#
#
# NAME:	 GRT − The Graph
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCGRAPH.svg
# RANK:	 43
# PRICE:	 0.13326767 USD
# CHANGE % IN 24H:	 2.31%
# MARKET CAP:	 1.193B USD
# CATEGORY:	 Data management & AI, Enterprise solutions, Web3
#
#
#
# NAME:	 EOS − EOS
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCEOS.svg
# RANK:	 44
# PRICE:	 1.0045033 USD
# CHANGE % IN 24H:	 −0.81%
# MARKET CAP:	 1.095B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 STX − Stacks
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCSTACKS.svg
# RANK:	 45
# PRICE:	 0.75939388 USD
# CHANGE % IN 24H:	 −5.01%
# MARKET CAP:	 1.045B USD
# CATEGORY:	 Smart contract platforms, NFTs & Collectibles, DeFi, Metaverse, Web3
#
#
#
# NAME:	 SAND − The Sandbox
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCSAND.svg
# RANK:	 46
# PRICE:	 0.56687091 USD
# CHANGE % IN 24H:	 2.26%
# MARKET CAP:	 1.04B USD
# CATEGORY:	 Gaming, NFTs & Collectibles, Metaverse, Marketplace
#
#
#
# NAME:	 AAVE − Aave
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCAAVE.svg
# RANK:	 47
# PRICE:	 71.029141 USD
# CHANGE % IN 24H:	 3.38%
# MARKET CAP:	 1.022B USD
# CATEGORY:	 DeFi, DAO, Lending & Borrowing
#
#
#
# NAME:	 MANA − Decentraland
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCMANA.svg
# RANK:	 48
# PRICE:	 0.53519385 USD
# CHANGE % IN 24H:	 2.49%
# MARKET CAP:	 1.005B USD
# CATEGORY:	 Gaming, NFTs & Collectibles, Metaverse
#
#
#
# NAME:	 EGLD − Elrond
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCEGLD.svg
# RANK:	 49
# PRICE:	 39.605349 USD
# CHANGE % IN 24H:	 0.47%
# MARKET CAP:	 1.005B USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 THETA − Theta Network
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCTHETA.svg
# RANK:	 50
# PRICE:	 0.99857241 USD
# CHANGE % IN 24H:	 3.41%
# MARKET CAP:	 998.572M USD
# CATEGORY:	 Social, media & Content, Web3, Smart contract platforms, Enterprise solutions
#
#
#
# NAME:	 RPL − Rocket Pool
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCRPL.svg
# RANK:	 51
# PRICE:	 50.942077 USD
# CHANGE % IN 24H:	 −1.28%
# MARKET CAP:	 984.671M USD
# CATEGORY:	 Derivatives, DeFi
#
#
#
# NAME:	 XTZ − Tezos
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCXTZ.svg
# RANK:	 52
# PRICE:	 0.99439067 USD
# CHANGE % IN 24H:	 2.30%
# MARKET CAP:	 931.368M USD
# CATEGORY:	 Smart contract platforms
#
#
#
# NAME:	 CFX − Conflux
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCCFX.svg
# RANK:	 53
# PRICE:	 0.32699251 USD
# CHANGE % IN 24H:	 6.64%
# MARKET CAP:	 911.83M USD
# CATEGORY:	 Smart contract platforms, DeFi, Web3, Interoperability
#
#
#
# NAME:	 FLOW − Flow
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCFLOW.svg
# RANK:	 54
# PRICE:	 0.87945944 USD
# CHANGE % IN 24H:	 4.37%
# MARKET CAP:	 911.296M USD
# CATEGORY:	 NFTs & Collectibles, Smart contract platforms, Sports
#
#
#
# NAME:	 BIT − BitDAO
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCBITD.svg
# RANK:	 55
# PRICE:	 0.4836 USD
# CHANGE % IN 24H:	 0.71%
# MARKET CAP:	 891.599M USD
# CATEGORY:	 DAO
#
#
#
# NAME:	 CHZ − Chiliz
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCCHZ.svg
# RANK:	 56
# PRICE:	 0.12767129 USD
# CHANGE % IN 24H:	 1.83%
# MARKET CAP:	 886.504M USD
# CATEGORY:	 Sports, Loyalty & Rewards
#
#
#
# NAME:	 AXS − Axie Infinity
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCAXS.svg
# RANK:	 57
# PRICE:	 7.6005261 USD
# CHANGE % IN 24H:	 2.13%
# MARKET CAP:	 882.699M USD
# CATEGORY:	 Gaming, NFTs & Collectibles, Metaverse
#
#
#
# NAME:	 IMX − Immutable X
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCIMXIMMUTABLEX.svg
# RANK:	 58
# PRICE:	 0.91260070 USD
# CHANGE % IN 24H:	 0.77%
# MARKET CAP:	 834.266M USD
# CATEGORY:	 Gaming, NFTs & Collectibles, Scaling, Marketplace, Developments tools
#
#
#
# NAME:	 RNDR − Render Token
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCRNDR.svg
# RANK:	 59
# PRICE:	 2.2643381 USD
# CHANGE % IN 24H:	 6.06%
# MARKET CAP:	 824.019M USD
# CATEGORY:	 Gaming, Distributed computing & Storage, Data management & AI, Metaverse, Web3
#
#
#
# NAME:	 KCS − KuCoin Token
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCKCS.svg
# RANK:	 60
# PRICE:	 7.884 USD
# CHANGE % IN 24H:	 1.40%
# MARKET CAP:	 764.549M USD
# CATEGORY:	 Centralized exchange
#
#
#
# NAME:	 USDP − Pax Dollar
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCUSDPPAXDOLLAR.svg
# RANK:	 61
# PRICE:	 0.9966 USD
# CHANGE % IN 24H:	 −0.24%
# MARKET CAP:	 754.977M USD
# CATEGORY:	 Stablecoins, Asset-backed Stablecoins, Cryptocurrencies
#
#
#
# NAME:	 CRV − Curve DAO Token
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCCRV.svg
# RANK:	 62
# PRICE:	 0.92805458 USD
# CHANGE % IN 24H:	 4.65%
# MARKET CAP:	 753.786M USD
# CATEGORY:	 Decentralized exchange, DeFi, DAO
#
#
#
# NAME:	 USDD − USDD
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCUSDD.svg
# RANK:	 63
# PRICE:	 0.9979 USD
# CHANGE % IN 24H:	 −0.06%
# MARKET CAP:	 736.772M USD
# CATEGORY:	 Stablecoins, Algorithmic Stablecoins
#
#
#
# NAME:	 NEO − Neo
# LOGO:	 https://s3-symbol-logo.tradingview.com/crypto/XTVCNEO.svg
# RANK:	 64
# PRICE:	 10.12288288 USD
# CHANGE % IN 24H:	 1.24%
# MARKET CAP:	 714.056M USD
# CATEGORY:	 Smart contract platforms, Enterprise solutions
#
#
#
# NAME:	 SUI − Sui
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
#       2 info_list = coin_info.find_all('td')
#       4 print('NAME:\t', info_list[0].find('a')['title'])
# ----> 5 print('LOGO:\t', info_list[0].find('img')['src'])
#       6 print('RANK:\t', info_list[1].text)
#       7 print('PRICE:\t', info_list[2].text)
#
# TypeError: 'NoneType' object is not subscriptable
