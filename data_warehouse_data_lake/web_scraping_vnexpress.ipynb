# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://vnexpress.net'

# %%
response_data = requests.get(url)
response_content = response_data.content
# response_content

# %%
soup = BeautifulSoup(response_content, 'html.parser')
# soup

# %%
soup_head = soup.find_all('head')[0]
# soup_head

# %%
soup_body = soup.find_all('body')[0]
# print(soup_body.prettify())

# %%
soup_body_news = soup_body.find_all('p', class_='description')
# len(soup_body_news), soup_body_news

# %%
for idx, news in enumerate(soup_body_news):
    print(idx)
#     print(news)
    print(news.find('a')['title'])
    print(news.find('a')['href'])
    print(news.find('a').text)
    print('\n')
# Out:
# 0
# Chủ tịch nước đến London dự lễ đăng quang của Vua Anh
# https://vnexpress.net/chu-tich-nuoc-den-london-du-le-dang-quang-cua-vua-anh-4601251.html
# Chủ tịch nước Võ Văn Thưởng tới London, bắt đầu các hoạt động trong chương trình tham dự lễ đăng quang của Quốc vương Charles III.
#
#
# 1
# Chủ tịch nước đến London dự lễ đăng quang của Vua Anh
# https://vnexpress.net/chu-tich-nuoc-den-london-du-le-dang-quang-cua-vua-anh-4601251.html
# Chủ tịch nước Võ Văn Thưởng đến sân bay quốc tế Hearthrow ở thủ đô London lúc 15h ngày 4/5 (21h giờ Hà Nội), bắt đầu chuyến công tác tới ngày 6/5, theo TTXVN. Trong chuyến đi, Chủ tịch nước dự kiến gặp Vua Charles III và Hoàng hậu Camilla, các lãnh đạo chính phủ, quốc hội và một số bộ trưởng Anh.Chủ tịch nư
#
#
# 2
# Hơn 20 thành phố Nga hủy duyệt binh Ngày Chiến thắng
# https://vnexpress.net/hon-20-thanh-pho-nga-huy-duyet-binh-ngay-chien-thang-4601226.html
# Ít nhất 21 thành phố Nga hủy duyệt binh kỷ niệm Ngày Chiến thắng trong Thế chiến II, sau loạt vụ tấn công UAV gần đây.
#
#
# 3
# Đề xuất áp thuế bất động sản thứ hai để tránh đầu cơ
# https://vnexpress.net/de-xuat-ap-thue-bat-dong-san-thu-hai-de-tranh-dau-co-4600835.html
# Trước việc vẫn có ý kiến đề nghị áp thuế luỹ tiến từ nhà thứ hai, Bộ Tài nguyên Môi trường cho biết sẽ tiếp thu, kiến nghị Chính phủ, Quốc hội nghiên cứu khi sửa luật về thuế.
#
#
# 4
# Chông chênh lao động hồi hương
# https://vnexpress.net/chong-chenh-lao-dong-hoi-huong-4601250.html
# Không có tay nghề, sau vài năm bán sức ở nước ngoài, họ trở về, loay hoay tìm việc.
#
#
# 5
# Giá điện sinh hoạt sẽ tăng ra sao?
# https://vnexpress.net/gia-dien-sinh-hoat-se-tang-ra-sao-4600981.html
# Với giá điện mới, mỗi tháng, hộ dùng 100-300 kWh phải trả thêm 5.100-18.700 đồng và trên 400 kWh là 27.200 đồng.
#
#
# 6
# Đề nghị Australia dừng lưu hành vật phẩm có hình ảnh 'cờ vàng'
# https://vnexpress.net/de-nghi-australia-dung-luu-hanh-vat-pham-co-hinh-anh-co-vang-4601040.html
# Việt Nam kiên quyết phản đối công ty Australia phát hành vật phẩm có hình ảnh "cờ vàng" và đề nghị dừng lưu hành.
#
#
# 7
# Từ ngày 1/7 lương hưu dự kiến thay đổi thế nào
# https://vnexpress.net/tu-ngay-1-7-luong-huu-du-kien-thay-doi-the-nao-4601197.html
# Lương hưu bình quân dự kiến tăng lên 5,2-6,3 triệu đồng mỗi tháng nếu đề xuất của Bộ Lao động Thương binh và Xã hội được thông qua.
#
#
# 8
# Thủ tướng Luxembourg thăm Văn Miếu và bảo tàng mỹ thuật
# https://vnexpress.net/thu-tuong-luxembourg-tham-van-mieu-va-bao-tang-my-thuat-4601158.html
# Thủ tướng Phạm Minh Chính và Thủ tướng Luxembourg Bettel cùng thăm Văn Miếu và đi bộ đến Bảo tàng Mỹ thuật Việt Nam, chiêm ngưỡng các tác phẩm điêu khắc, hội họa.
#
#
# 9
# Nga cáo buộc Mỹ đứng sau vụ tấn công Điện Kremlin
# https://vnexpress.net/nga-cao-buoc-my-dung-sau-vu-tan-cong-dien-kremlin-4601153.html
# Điện Kremlin cho rằng Mỹ là bên đứng sau trong vụ "Ukraine tấn công Điện Kremlin bằng UAV", tuyên bố sẽ điều tra khẩn cấp sự viêc.
#
#
# 10
# Bị phạt 17 triệu đồng vì chạy ngược chiều cao tốc Dầu Giây - Phan Thiết
# https://vnexpress.net/bi-phat-17-trieu-dong-vi-chay-nguoc-chieu-cao-toc-dau-giay-phan-thiet-4601205.html
# Bình ThuậnNam tài xế 45 tuổi bị phạt 17 triệu đồng, tước bằng lái 6 tháng, do chạy ôtô hơn 100 km/h ngược chiều trên cao tốc Dầu Giây - Phan Thiết mới hoạt động.
#
#
# 11
# PSG bênh vực Messi, Neymar
# https://vnexpress.net/psg-benh-vuc-messi-neymar-4601164.html
# PSG ra thông báo bênh vực các cầc thủ ngôi sao và chỉ trích nhóm CĐV quá khích biểu tình ngoài trụ sở CLB.
#
#
# 12
# HLV Indonesia tính xa cho bán kết SEA Games
# https://vnexpress.net/hlv-indonesia-tinh-xa-cho-ban-ket-sea-games-4601218.html
# CampuchiaTheo HLV Indra Sjafri, Indonesia thay nhiều vị trí trong trận thắng Myanmar 5-0 chiều 4/5 nhằm giữ lực lượng tốt nhất cho bán kết SEA Games 32.
#
#
# 13
# Du khách phải cách khu vực sạt lở ở Bàu Trắng 100 m
# https://vnexpress.net/du-khach-phai-cach-khu-vuc-sat-lo-o-bau-trang-100-m-4601217.html
# Bình ThuậnKhu vực sạt lở hơn 1.500 m2 ở đồi cát Trinh Nữ kề hồ nước tự nhiên đã được rào lại, du khách không được phép đến gần để tránh rủi ro.
#
#
# 14
# Giá xăng giảm hơn 1.000 đồng mỗi lít
# https://vnexpress.net/gia-xang-moi-nhat-hom-nay-4601019.html
# Mỗi lít xăng giảm 1.250-1.310 đồng, các mặt hàng dầu cũng hạ 340-1.140 đồng, từ 15h hôm nay.
#
#
# 15
# Tượng cánh tay bên bờ biển bị sóng đánh bong tróc
# https://vnexpress.net/tuong-canh-tay-ben-bo-bien-bi-song-danh-bong-troc-4601013.html
# Thanh HóaPhần đế của 5 bức tượng cánh tay trên bờ biển Hải Tiến, huyện Hoằng Hóa bị sóng đánh bong tróc, trơ đinh vít khiến nhà chức trách phải căng dây, cấm du khách đến gần trong thời gian hoàn thiện.
#
#
# 16
# Tăng bảo vệ và camera để ngăn vẽ bậy Metro số 1
# https://vnexpress.net/tang-bao-ve-va-camera-de-ngan-ve-bay-metro-so-1-4601194.html
# Ngoài lắp thêm camera, đèn chiếu sáng, nơi tập kết 17 đoàn tàu thuộc Metro số 1 được tăng cường bảo vệ với ca trực dày hơn, sau vụ tàu của dự án bị bôi bẩn.
#
#
# 17
# Giải cứu cá voi gần 300 kg mắc cạn
# https://vnexpress.net/giai-cuu-ca-voi-gan-300-kg-mac-can-4601229.html
# Bình ThuậnCá voi dài khoảng 4 m, nặng gần 300 kg, mắc cạn ở bờ biển thị xã La Gi, được người dân giải cứu, chiều 4/5.
#
#
# 18
# Cứu hộ hai toa tàu SE1 trật khỏi đường ray
# https://vnexpress.net/cuu-ho-hai-toa-tau-se1-trat-khoi-duong-ray-4601133.html
# Thừa Thiên - HuếSau 4 tiếng, hai toa tàu khách SE1 đã được cần cẩu 100 tấn cùng hàng chục công nhân giải phóng khỏi hiện trường sau vụ trật đường ray.
#
#
# 19
# 'Siêu trộm' đột nhập loạt nhà dân ở Đăk Lăk bị bắt
# https://video.vnexpress.net/tin-tuc/phap-luat/sieu-trom-dot-nhap-loat-nha-dan-o-dak-lak-bi-bat-4601152.html
# Liên tục thay đổi mũ, khẩu trang bịt mặt để tránh nhận dạng, từ đầu năm đến nay, Nguyễn Duy Khánh (29 tuổi) đột nhập 10 nhà dân ở TP Buôn Ma Thuột, trộm tài sản.
#
#
# 20
# Sếp về hưu lĩnh 18 năm tù trong vụ lừa chiếm đất vàng của đại gia
# https://vnexpress.net/sep-ve-huu-linh-18-nam-tu-trong-vu-lua-chiem-dat-vang-cua-dai-gia-4601001.html
# Hà NộiÔng Lương Thế Hiển, cựu Phó chánh Văn phòng Sở Tài nguyên Môi trường, bị phạt 18 năm tù do chiếm 676 m2 "đất vàng" trên phố Bà Triệu khi được nhờ đứng tên.
#
#
# 21
# Chủ tịch Fed cảnh báo không thể cứu Mỹ khỏi vỡ nợ
# https://vnexpress.net/chu-tich-fed-canh-bao-khong-the-cuu-my-khoi-vo-no-4600931.html
# Ông Jerome Powell cho rằng nếu không nới trần nợ công sẽ là rủi ro chưa từng có tiền lệ và gây ra hậu quả khó lường với Mỹ.
#
#
# 22
# Cầu thủ Việt Nam xả hơi sau chiến thắng Singapore
# https://vnexpress.net/cau-thu-viet-nam-xa-hoi-sau-chien-thang-singapore-4601125.html
# CampuchiaMột ngày sau khi đánh bại Singapore ở lượt hai bảng B SEA Games 32, HLV Philippe Troussier cho cầu thủ thả lỏng rồi thư giãn ở hồ bơi, thay vì tập chuyên môn.
#
#
# 23
# Phong cách huấn luyện viên Keisuke Honda
# https://vnexpress.net/phong-cach-huan-luyen-vien-keisuke-honda-4601006.html
# Keisuke Honda - huấn luyện viên bóng đá nam Campuchia - biến hóa phong cách từ năng động đến lịch lãm.
#
#
# 24
# Lập trang web mạo danh cơ quan báo chí để đăng bài, tống tiền
# https://vnexpress.net/lap-trang-web-mao-danh-co-quan-bao-chi-de-dang-bai-tong-tien-4600949.html
# Hà NộiNguyễn Quang Dũng chỉ đạo đồng phạm lấy thông tin về các công trình xây dựng có dấu hiệu sai phạm sau đó đăng lên web giả để đe dọa, yêu cầu chủ tịch phường chi tiền gỡ bài.
#
#
# 25
# Hai VĐV Việt Nam vào top ngôi sao đáng xem tại SEA Games 32
# https://vnexpress.net/hai-vdv-viet-nam-vao-top-ngoi-sao-dang-xem-tai-sea-games-32-4600888.html
# Chân chạy Nguyễn Thị Oanh và võ sĩ quyền Anh Nguyễn Thị Tâm được hãng thông tấn AFP đánh giá thuộc nhóm VĐV đẳng cấp nhất tại SEA Games 32.
#
#
# 26
# Nhà gốm hình bàn xoay hút khách trải nghiệm
# https://video.vnexpress.net/tin-tuc/du-lich/nha-gom-hinh-ban-xoay-hut-khach-trai-nghiem-4600725.html
# Hà NộiHàng chục nghìn người tham quan, trải nghiệm làm gốm tại bảo tàng gốm hình bàn xoay ở huyện Gia Lâm.
#
#
# 27
# Công nhân rời TP HCM về quê tìm việc
# https://vnexpress.net/cong-nhan-roi-tp-hcm-ve-que-tim-viec-4600784.html
# Nhà máy giảm việc, hạn chế tuyển lao động, chi phí ở thành phố tăng cao nên nhiều công nhân hồi hương tìm cơ hội.
